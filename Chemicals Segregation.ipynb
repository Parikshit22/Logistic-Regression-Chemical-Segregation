# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
x_data = pd.read_csv("Logistic_X_Train.csv")
y_data = pd.read_csv("Logistic_Y_Train.csv")
print(x_data.head())
print(y_data.head())
x_data = x_data.values
y_data = y_data.values
y_data = np.reshape(y_data,(-1,))
print(y_data.shape)
# Out:
#          f1        f2        f3
# 0 -1.239375  0.749101 -0.528515
# 1 -1.036070  0.801436 -1.283712
# 2 -0.615579  1.579521 -1.391927
# 3  1.335978  1.348651  1.433564
# 4  0.658925  1.300019  0.571603
#    label
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
# (3000,)

# %%
fig = plt.figure(figsize = (10,10))
axes = fig.gca(projection = '3d')
axes.scatter(x_data[:,0],x_data[:,1],x_data[:,2],c = y_data)
plt.show()

# %%
reg = LogisticRegression()
reg.fit(x_data,y_data)
x_test = pd.read_csv("Logistic_X_Test.csv")
x_test = x_test.values
pred = reg.predict(x_test)
dict = {"label":pred}
ans  = pd.DataFrame(dict)
ans.to_csv("file.csv")
# Out:
# C:\Users\MUJ\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
